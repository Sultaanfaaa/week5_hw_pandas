# %%
import pandas as pd

# %%
pd.read_csv('/content/sultan_110')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.read_csv('/content/sultan_110')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
# ...

# %%
import pandas as pd

# %%
df_injured=pd.read_excel('Sultan_110.xls')
df_injured
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 0       Muharram    Riyadh   364      29              291               102
# 1          Safar    Riyadh   387      46              276               157
# 2      Rabi_Awal    Riyadh   361      94              284               171
# 3    Rabie_Thani    Riyadh   378      49              295               132
# 4    Jumada-Awal    Riyadh   311      47              262                96
# ..           ...       ...   ...     ...              ...               ...
# 187      Shabaan  Qurayyat    21       1               15                 7
# 188      Ramadan  Qurayyat    30       9                8                31
# 189       Shawal  Qurayyat    15       1                6                10
# 190  Dhu-AlQadah  Qurayyat    19       0                8                11
# 191  Dhul-Hijjah  Qurayyat    20       2               13                 9
#
# ...

# %%
df_deaths.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_deaths.head()
#
# NameError: name 'df_deaths' is not defined

# %%
df_Injured()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_Injured()
#
# NameError: name 'df_Injured' is not defined

# %%
excel(r'C:\Users\surfa\Desktop\tmb\sultan_110.xls')
df_deaths=pd.read_excel(r'C:\Users\surfa\Desktop\tmb\sultan_110.xls')
pd.read excel(r'C:\Users\surfa\Desktop\tmb\sultan_110.xls')
df_Injured=pd.read_excel(r'C:\Users\surfa\Desktop\tmb\sultan_110.xls') 
df_deaths
df_Injured
# Out:
#   Cell In[16], line 3
#     pd.read excel(r'C:\Users\surfa\Desktop\tmb\sultan_110.xls')
#             ^
# SyntaxError: invalid syntax

# %%
pd.read_excel(r'C:\Users\tmb\Desktop\sultan_110.xls')
df_deaths=pd.read_excel(r'C:\Users\tmb\Desktop\sultan_110.xls')
pd.read_excel(r'C:\Users\tmb\Desktop\sultan_110.xls')
df_Injured=pd.read_excel(r'C:\Users\tmb\Desktop\sultan_110.xls')
df_deaths
df_Injured
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 0       Muharram    Riyadh   364      29              291               102
# 1          Safar    Riyadh   387      46              276               157
# 2      Rabi_Awal    Riyadh   361      94              284               171
# 3    Rabie_Thani    Riyadh   378      49              295               132
# 4    Jumada-Awal    Riyadh   311      47              262                96
# ..           ...       ...   ...     ...              ...               ...
# 187      Shabaan  Qurayyat    21       1               15                 7
# 188      Ramadan  Qurayyat    30       9                8                31
# 189       Shawal  Qurayyat    15       1                6                10
# 190  Dhu-AlQadah  Qurayyat    19       0                8                11
# 191  Dhul-Hijjah  Qurayyat    20       2               13                 9
#
# ...

# %%
df_deaths.head()
# Out:
#      the month  Region  Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh   364      29              291               102
# 1        Safar  Riyadh   387      46              276               157
# 2    Rabi_Awal  Riyadh   361      94              284               171
# 3  Rabie_Thani  Riyadh   378      49              295               132
# 4  Jumada-Awal  Riyadh   311      47              262                96
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0        66             97            126             73            31    213
# 1        44            117            145             79            48    271
# 2       115            124            108             89            19    278
# 3       132            119            103             51            22    238
# 4        61            111             89             52            45    207
#
#    Non-Saudi
# 0        180
# 1        162
# 2        177
# ...

# %%
df_Injured.columns
# Out:
# Index(['the month', 'Region', 'Male', 'Female', 'Inside the city',
#        'outside the city', 'Under 18', 'From 18 to 30', 'From 30 to 40',
#        'From 40 to 50', 'More than 50', 'Saudi', 'Non-Saudi'],
#       dtype='object')

# %%
df_Injured.shape
# Out:
# (192, 13)

# %%
df_Injured.isnull()
# Out:
#      the month  Region   Male  Female  Inside the city  outside the city  \
# 0        False   False  False   False            False             False
# 1        False   False  False   False            False             False
# 2        False   False  False   False            False             False
# 3        False   False  False   False            False             False
# 4        False   False  False   False            False             False
# ..         ...     ...    ...     ...              ...               ...
# 187      False   False  False   False            False             False
# 188      False   False  False   False            False             False
# 189      False   False  False   False            False             False
# 190      False   False  False   False            False             False
# 191      False   False  False   False            False             False
#
#      Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  \
# ...

# %%
df_Injured.dtypes
# Out:
# the month           object
# Region              object
# Male                 int64
# Female               int64
# Inside the city      int64
# outside the city     int64
# Under 18             int64
# From 18 to 30        int64
# From 30 to 40        int64
# From 40 to 50        int64
# More than 50         int64
# Saudi                int64
# Non-Saudi            int64
# dtype: object

# %%
df_Injured.الشهر
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11556\1846622326.py in ?()
# ----> 1 df_Injured.الشهر
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'الشهر'

# %%
df_Injured.الشهر
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11556\1846622326.py in ?()
# ----> 1 df_Injured.الشهر
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'الشهر'

# %%
df_Injured. month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11556\1824075121.py in ?()
# ----> 1 df_Injured. month
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'month'

# %%
df_Injured.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11556\1513036266.py in ?()
# ----> 1 df_Injured.month
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'month'

# %%
IS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 IS
#
# NameError: name 'IS' is not defined

# %%
df_Injured.month
df_Injured
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11556\1855499249.py in ?()
# ----> 1 df_Injured.month
#       2 df_Injured
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'month'

# %%
df_Injured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   the month         192 non-null    object
#  1   Region            192 non-null    object
#  2   Male              192 non-null    int64
#  3   Female            192 non-null    int64
#  4   Inside the city   192 non-null    int64
#  5   outside the city  192 non-null    int64
#  6   Under 18          192 non-null    int64
#  7   From 18 to 30     192 non-null    int64
#  8   From 30 to 40     192 non-null    int64
#  9   From 40 to 50     192 non-null    int64
#  10  More than 50      192 non-null    int64
#  11  Saudi             192 non-null    int64
#  12  Non-Saudi         192 non-null    int64
# dtypes: int64(11), object(2)
# memory usage: 19.6+ KB

# %%
df_Injured.tail()
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 187      Shabaan  Qurayyat    21       1               15                 7
# 188      Ramadan  Qurayyat    30       9                8                31
# 189       Shawal  Qurayyat    15       1                6                10
# 190  Dhu-AlQadah  Qurayyat    19       0                8                11
# 191  Dhul-Hijjah  Qurayyat    20       2               13                 9
#
#      Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  \
# 187        10              5              5              2             0
# 188        16              6             13              2             2
# 189         1              8              5              1             1
# 190         1             16              1              1             0
# 191         6              6              5              2             3
#
#      Saudi  Non-Saudi
# 187     19          3
# 188     27         12
# ...

# %%
df_Injured.describe()
# Out:
#              Male      Female  Inside the city  outside the city    Under 18  \
# count  192.000000  192.000000       192.000000        192.000000  192.000000
# mean   131.843750   25.536458        78.005208         79.375000   22.598958
# std     94.417956   22.501628        75.757570         59.566629   21.290821
# min     11.000000    0.000000         0.000000          6.000000    0.000000
# 25%     50.500000    6.000000        16.750000         27.000000    8.000000
# 50%    116.500000   18.000000        50.000000         61.500000   16.000000
# 75%    200.250000   41.000000       111.500000        129.250000   31.000000
# max    387.000000   94.000000       295.000000        280.000000  132.000000
#
#        From 18 to 30  From 30 to 40  From 40 to 50  More than 50       Saudi  \
# count     192.000000     192.000000     192.000000    192.000000  192.000000
# mean       48.500000      41.671875      27.260417     17.348958  102.807292
# ...

# %%
df_Injured.isnull().sum()
# Out:
# the month           0
# Region              0
# Male                0
# Female              0
# Inside the city     0
# outside the city    0
# Under 18            0
# From 18 to 30       0
# From 30 to 40       0
# From 40 to 50       0
# More than 50        0
# Saudi               0
# Non-Saudi           0
# dtype: int64

# %%
df_inj_clean= df_Injured.drop(['المجموع.3','المجموع','المجموع.2','المجموع.1'], axls =1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 df_inj_clean= df_Injured.drop(['المجموع.3','المجموع','المجموع.2','المجموع.1'], axls =1)
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'axls'

# %%
df_Injured.drop(['المجموع.3','المجموع','المجموع.2','المجموع.1'], axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df_Injured.drop(['المجموع.3','المجموع','المجموع.2','المجموع.1'], axis =1)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
df_Injured['Male'].max()
# Out:
# 387

# %%
df_Injured['Male'].min()
# Out:
# 11

# %%
df_Injured.sample(10)
# Out:
#        the month           Region  Male  Female  Inside the city  \
# 60      Muharram          Al-Jouf    30       4                8
# 39   Rabie_Thani  Northern_border    35       7               16
# 50     Rabi_Awal            Tabuk   115      14               44
# 64   Jumada-Awal          Al-Jouf    18       2                6
# 110    Rabi_Awal           Albaha    52      15               22
# 130  Dhu-AlQadah            Assir   130      26               31
# 154  Dhu-AlQadah           Jeddah   200      39              176
# 66         Rajab          Al-Jouf    17       4                4
# 163      Shabaan             Taif   269      31              141
# 7        Shabaan           Riyadh   350      43              273
#
#      outside the city  Under 18  From 18 to 30  From 30 to 40  From 40 to 50  \
# 60                 26         7             11             11              4
# 39                 26        11             16             10              3
# ...

# %%
df_Injured["Region"].unique()
# Out:
# array(['Riyadh', 'Madinah', 'Eastern_Province', 'Northern_border',
#        'Tabuk', 'Al-Jouf', 'Hail', 'Najran', 'Qassim', 'Albaha', 'Assir',
#        'Jazan', 'Jeddah', 'Taif', 'Makkah', 'Qurayyat'], dtype=object)

# %%
df_Injured.loc[~ df_Injured["Region"].isnull()]
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 0       Muharram    Riyadh   364      29              291               102
# 1          Safar    Riyadh   387      46              276               157
# 2      Rabi_Awal    Riyadh   361      94              284               171
# 3    Rabie_Thani    Riyadh   378      49              295               132
# 4    Jumada-Awal    Riyadh   311      47              262                96
# ..           ...       ...   ...     ...              ...               ...
# 187      Shabaan  Qurayyat    21       1               15                 7
# 188      Ramadan  Qurayyat    30       9                8                31
# 189       Shawal  Qurayyat    15       1                6                10
# 190  Dhu-AlQadah  Qurayyat    19       0                8                11
# 191  Dhul-Hijjah  Qurayyat    20       2               13                 9
#
# ...

# %%
df_Injured.loc[~ df_Injured["Region"].isnull()]
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 0       Muharram    Riyadh   364      29              291               102
# 1          Safar    Riyadh   387      46              276               157
# 2      Rabi_Awal    Riyadh   361      94              284               171
# 3    Rabie_Thani    Riyadh   378      49              295               132
# 4    Jumada-Awal    Riyadh   311      47              262                96
# ..           ...       ...   ...     ...              ...               ...
# 187      Shabaan  Qurayyat    21       1               15                 7
# 188      Ramadan  Qurayyat    30       9                8                31
# 189       Shawal  Qurayyat    15       1                6                10
# 190  Dhu-AlQadah  Qurayyat    19       0                8                11
# 191  Dhul-Hijjah  Qurayyat    20       2               13                 9
#
# ...

# %%
df_Injured.dropna(inplace = True)

# %%
df_Injured.convert_dtypes(int)
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 0       Muharram    Riyadh   364      29              291               102
# 1          Safar    Riyadh   387      46              276               157
# 2      Rabi_Awal    Riyadh   361      94              284               171
# 3    Rabie_Thani    Riyadh   378      49              295               132
# 4    Jumada-Awal    Riyadh   311      47              262                96
# ..           ...       ...   ...     ...              ...               ...
# 187      Shabaan  Qurayyat    21       1               15                 7
# 188      Ramadan  Qurayyat    30       9                8                31
# 189       Shawal  Qurayyat    15       1                6                10
# 190  Dhu-AlQadah  Qurayyat    19       0                8                11
# 191  Dhul-Hijjah  Qurayyat    20       2               13                 9
#
# ...

# %%
df_Injured
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 0       Muharram    Riyadh   364      29              291               102
# 1          Safar    Riyadh   387      46              276               157
# 2      Rabi_Awal    Riyadh   361      94              284               171
# 3    Rabie_Thani    Riyadh   378      49              295               132
# 4    Jumada-Awal    Riyadh   311      47              262                96
# ..           ...       ...   ...     ...              ...               ...
# 187      Shabaan  Qurayyat    21       1               15                 7
# 188      Ramadan  Qurayyat    30       9                8                31
# 189       Shawal  Qurayyat    15       1                6                10
# 190  Dhu-AlQadah  Qurayyat    19       0                8                11
# 191  Dhul-Hijjah  Qurayyat    20       2               13                 9
#
# ...

# %%
df_Injured.isnull().sum()
# Out:
# the month           0
# Region              0
# Male                0
# Female              0
# Inside the city     0
# outside the city    0
# Under 18            0
# From 18 to 30       0
# From 30 to 40       0
# From 40 to 50       0
# More than 50        0
# Saudi               0
# Non-Saudi           0
# dtype: int64

# %%
df_Injured['Region'].unique()
# Out:
# array(['Riyadh', 'Madinah', 'Eastern_Province', 'Northern_border',
#        'Tabuk', 'Al-Jouf', 'Hail', 'Najran', 'Qassim', 'Albaha', 'Assir',
#        'Jazan', 'Jeddah', 'Taif', 'Makkah', 'Qurayyat'], dtype=object)

# %%
df_Injured['Region'].replace({'اRiyadh- عدد الأشخاص المصابين حسب الجنس':"Riyadh"},inplace=True)
df_Injured.head()
# Out:
#      the month  Region  Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh   364      29              291               102
# 1        Safar  Riyadh   387      46              276               157
# 2    Rabi_Awal  Riyadh   361      94              284               171
# 3  Rabie_Thani  Riyadh   378      49              295               132
# 4  Jumada-Awal  Riyadh   311      47              262                96
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0        66             97            126             73            31    213
# 1        44            117            145             79            48    271
# 2       115            124            108             89            19    278
# 3       132            119            103             51            22    238
# 4        61            111             89             52            45    207
#
#    Non-Saudi
# 0        180
# 1        162
# 2        177
# ...

# %%
df_Injured['Region'].replace({'Riyadh- عدد الأشخاص المصابين حسب الجنس':"Madinah"},inplace=True)
df_Injured.head()
# Out:
#      the month  Region  Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh   364      29              291               102
# 1        Safar  Riyadh   387      46              276               157
# 2    Rabi_Awal  Riyadh   361      94              284               171
# 3  Rabie_Thani  Riyadh   378      49              295               132
# 4  Jumada-Awal  Riyadh   311      47              262                96
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0        66             97            126             73            31    213
# 1        44            117            145             79            48    271
# 2       115            124            108             89            19    278
# 3       132            119            103             51            22    238
# 4        61            111             89             52            45    207
#
#    Non-Saudi
# 0        180
# 1        162
# 2        177
# ...

# %%
df_deaths
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 0       Muharram    Riyadh   364      29              291               102
# 1          Safar    Riyadh   387      46              276               157
# 2      Rabi_Awal    Riyadh   361      94              284               171
# 3    Rabie_Thani    Riyadh   378      49              295               132
# 4    Jumada-Awal    Riyadh   311      47              262                96
# ..           ...       ...   ...     ...              ...               ...
# 187      Shabaan  Qurayyat    21       1               15                 7
# 188      Ramadan  Qurayyat    30       9                8                31
# 189       Shawal  Qurayyat    15       1                6                10
# 190  Dhu-AlQadah  Qurayyat    19       0                8                11
# 191  Dhul-Hijjah  Qurayyat    20       2               13                 9
#
# ...

# %%
df_Injured.sample(50)
# Out:
#         the month            Region  Male  Female  Inside the city  \
# 6           Rajab            Riyadh   345      38              250
# 1           Safar            Riyadh   387      46              276
# 61          Safar           Al-Jouf    30       6               12
# 179   Dhul-Hijjah            Makkah   282      56              189
# 112   Jumada-Awal            Albaha    96      10               30
# 12       Muharram           Madinah   155      21               79
# 155   Dhul-Hijjah            Jeddah   220      34              175
# 35    Dhul-Hijjah  Eastern_Province   179      69               98
# 170     Rabi_Awal            Makkah   234      69              143
# 83    Dhul-Hijjah              Hail    51      11               35
# 165        Shawal              Taif   268      41              202
# 76    Jumada-Awal              Hail    11      42               34
# 78          Rajab              Hail    74       9               62
# ...

# %%
df_Injured
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 0       Muharram    Riyadh   364      29              291               102
# 1          Safar    Riyadh   387      46              276               157
# 2      Rabi_Awal    Riyadh   361      94              284               171
# 3    Rabie_Thani    Riyadh   378      49              295               132
# 4    Jumada-Awal    Riyadh   311      47              262                96
# ..           ...       ...   ...     ...              ...               ...
# 187      Shabaan  Qurayyat    21       1               15                 7
# 188      Ramadan  Qurayyat    30       9                8                31
# 189       Shawal  Qurayyat    15       1                6                10
# 190  Dhu-AlQadah  Qurayyat    19       0                8                11
# 191  Dhul-Hijjah  Qurayyat    20       2               13                 9
#
# ...

# %%
df_deaths
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 0       Muharram    Riyadh   364      29              291               102
# 1          Safar    Riyadh   387      46              276               157
# 2      Rabi_Awal    Riyadh   361      94              284               171
# 3    Rabie_Thani    Riyadh   378      49              295               132
# 4    Jumada-Awal    Riyadh   311      47              262                96
# ..           ...       ...   ...     ...              ...               ...
# 187      Shabaan  Qurayyat    21       1               15                 7
# 188      Ramadan  Qurayyat    30       9                8                31
# 189       Shawal  Qurayyat    15       1                6                10
# 190  Dhu-AlQadah  Qurayyat    19       0                8                11
# 191  Dhul-Hijjah  Qurayyat    20       2               13                 9
#
# ...

# %%
df_deaths.head()
# Out:
#      the month  Region  Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh   364      29              291               102
# 1        Safar  Riyadh   387      46              276               157
# 2    Rabi_Awal  Riyadh   361      94              284               171
# 3  Rabie_Thani  Riyadh   378      49              295               132
# 4  Jumada-Awal  Riyadh   311      47              262                96
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0        66             97            126             73            31    213
# 1        44            117            145             79            48    271
# 2       115            124            108             89            19    278
# 3       132            119            103             51            22    238
# 4        61            111             89             52            45    207
#
#    Non-Saudi
# 0        180
# 1        162
# 2        177
# ...

# %%
df_deaths.columns
# Out:
# Index(['the month', 'Region', 'Male', 'Female', 'Inside the city',
#        'outside the city', 'Under 18', 'From 18 to 30', 'From 30 to 40',
#        'From 40 to 50', 'More than 50', 'Saudi', 'Non-Saudi'],
#       dtype='object')

# %%
df_Injured ["Region"].replace({'Riyadh','-عــد د الأشخاص المتوفين حـسب الجـنس'},inplace = True)

# %%
df_Injured.sample(50)
# Out:
#         the month            Region  Male  Female  Inside the city  \
# 170     Rabi_Awal            Makkah   234      69              143
# 77   Jumada-Thani              Hail    60       3               54
# 61          Safar           Al-Jouf    30       6               12
# 22    Dhu-AlQadah           Madinah   156      42               65
# 24       Muharram  Eastern_Province   134      84              142
# 44        Ramadan   Northern_border    38       7               21
# 169         Safar            Makkah   180      44               98
# 165        Shawal              Taif   268      41              202
# 116       Ramadan            Albaha    80       4               42
# 125  Jumada-Thani             Assir   128      34               16
# 34    Dhu-AlQadah  Eastern_Province   168      44               84
# 179   Dhul-Hijjah            Makkah   282      56              189
# 107   Dhul-Hijjah            Qassim    69       9               56
# ...

# %%
df_Injured.describe()
# Out:
#              Male      Female  Inside the city  outside the city    Under 18  \
# count  192.000000  192.000000       192.000000        192.000000  192.000000
# mean   131.843750   25.536458        78.005208         79.375000   22.598958
# std     94.417956   22.501628        75.757570         59.566629   21.290821
# min     11.000000    0.000000         0.000000          6.000000    0.000000
# 25%     50.500000    6.000000        16.750000         27.000000    8.000000
# 50%    116.500000   18.000000        50.000000         61.500000   16.000000
# 75%    200.250000   41.000000       111.500000        129.250000   31.000000
# max    387.000000   94.000000       295.000000        280.000000  132.000000
#
#        From 18 to 30  From 30 to 40  From 40 to 50  More than 50       Saudi  \
# count     192.000000     192.000000     192.000000    192.000000  192.000000
# mean       48.500000      41.671875      27.260417     17.348958  102.807292
# ...

# %%
df_Injured.loc[df_Injured["Region"].isnull()]
# Out:
# Empty DataFrame
# Columns: [the month, Region, Male, Female, Inside the city, outside the city, Under 18, From 18 to 30, From 30 to 40, From 40 to 50, More than 50, Saudi, Non-Saudi]
# Index: []

# %%
df_Injured = df_Injured.drop(["the month","Region" ], axis = 1)
df_Injured
# Out:
#      Male  Female  Inside the city  outside the city  Under 18  From 18 to 30  \
# 0     364      29              291               102        66             97
# 1     387      46              276               157        44            117
# 2     361      94              284               171       115            124
# 3     378      49              295               132       132            119
# 4     311      47              262                96        61            111
# ..    ...     ...              ...               ...       ...            ...
# 187    21       1               15                 7        10              5
# 188    30       9                8                31        16              6
# 189    15       1                6                10         1              8
# 190    19       0                8                11         1             16
# 191    20       2               13                 9         6              6
#
# ...

# %%
sns.heatmap(df_Injured_droop.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 sns.heatmap(df_Injured_droop.corr(),annot=True)
#
# NameError: name 'sns' is not defined

# %%
sns.heatmap(df_dead_clean_droop.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 sns.heatmap(df_dead_clean_droop.corr(),annot=True)
#
# NameError: name 'sns' is not defined

# %%
(df_Injured_droop.corr(),annot=True)
# Out:
#   Cell In[144], line 1
#     (df_Injured_droop.corr(),annot=True)
#                              ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
(df_Injured.corr(),==True)
# Out:
#   Cell In[163], line 1
#     (df_Injured.corr(),==True)
#                        ^
# SyntaxError: invalid syntax

# %%
(df_Injured(),annot=True)
# Out:
#   Cell In[151], line 1
#     (df_Injured()annot=True)
#      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
(x='Saudi' , y='Male', data= df_Injured='Region',fit_reg=False)
# Out:
#   Cell In[172], line 1
#     (x='Saudi' , y='Male', data= df_Injured='Region',fit_reg=False)
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
